# %% [markdown]
# ## Amazon Replica

# %%
We will build a basic replica of Amazon, the e-commerce application.

The application will support two roles:

Seller
Customer


Seller will have the following functionalities:



Register and log in to the application.

On login, these menu options will be available: Create Product, Update Product, View Product, Delete Product

Create Product option will create a new product with the following information: Product Name, Manufacturer Name, Price, Quantity. For eg, 1piece, 200gm, 1.3litre, etc, Stock. Total remaining products in the stock.

Update product will update the product using the ProductID

View product will show the product using the ProductID

Delete product will delete the product using the ProductID





The customer will have the following functionalities:

Register and log in to the application

Registration will require the following information: Full Name, Contact Number, Email, Address

On login, these menu items will be available: New Order, Order History, Cancel Order

New Order will show a list of products and the user will enter an array of product IDs to select the product(s). For eg,
ID: 1; Apple iPad Pro 11in; Price: INR 80000; 1piece
ID: 2; Apple Airpods; Price: INR 22,000; 1 piece
ID:3; Playstation 5; Price: INR 49,999; 1 piece

If user wants to select Apple iPad and Apple Airpods then input will be [1, 2]

Order History will show the list of past orders.

Cancel order will cancel orders based on OrderID.

# %%
 
class amazon:
    def __init__(self):
        self.products={}
        self.product=[] 
            #Product Name, Manufacturer Name, Price, Quantity. For eg, 1piece, 200gm, 1.3litre, etc, Stock. Total remaining products in the stock
        
    def create_product(self):
        
        self.product_id=input(" \n  Create product ID  ")
        
        n=input(" \n Enter the product Name ")
        self.product.append(n)
        mn=input(" \n Enter the Manufacturer Name ")          
                                                              
        self.product.append(mn)
        p=int(input(" \n Enter the price "))
        self.product.append(p)
        q=int(input(" \n Enter the quantity of product "))
        self.product.append(q)                              
        self.products[self.product_id]=self.product
        
        print(" \n  products in dict ",self.products)
        
    def update_product(self):
            pid=input(" \n Enter your product id ")
            if pid in self.products:
                a=int(input(" \n  Enter \n 1 - To change product id \n 2 - To change product name \n 3 - To change manufacturer  name  \n 4 - To change the product price \n 5 - To change the quantity "))
                if a==1:
                    b=self.products[pid]
                    self.products.pop(pid)
                    c=input(" \n Enter new id for that product : ")
                    self.products[c]=b
                    print(" \n  Your product's has been changed sucessfully ")
                if a==2:
                    self.products[pid][0]=input("Please enter new name to the product")
                    print(" \n  Your product's name has been changed sucessfully ")
                if a==3:
                    self.products[pid][1]=input("Please enter new Manufacturer Name ")
                    print(" \n  Your product's Manufacturer Name has been changed sucessfully ")
                if a==4:
                    self.products[pid][2]=int(input("Please enter new price "))
                    print(" \n  Your product's price has been changed sucessfully ")
                if a==5:
                    print(" \n Yours product's current quantity is  ",self.products[pid][3])
                    s=int(input(" \n Enter \n 1 - To add quantity manually \n 2 - To reduce quantity manually \n  3 - To Change the quantity completely" ))
                    if s==1:
                        ad=int(input(" \n Enter the quantity that need to be added "))

                        self.products[pid][3]=self.products[pid][3]+ad
                        print(" \n  Your product's quantity added sucessfully  & your current quantity is ",self.products[pid][3])
                    if s==2:
                        su=int(input(" \n Enter the quantity that need to be added "))

                        self.products[pid][3]=self.products[pid][3]-su
                        print(" \n  Your product's quantity reduced sucessfully  & your current quantity is ",self.products[pid][3])
                    if s==3:
                        nv=int(input(" \n  Enter the product's quantity that need to be displayed : "))
                        self.products[pid][3]=nv
                        
                   
                else:
                    print(" \n  You had entered invalid input please try again ")
            else:
                print(" \n  OOPS !! ...Your product id is not found ")
            
    def view_product_details(self):                          
        
        pid=input(" \n Enter your product id ")
        if pid in self.products:
            a=int(input(" \n  Enter \n 1 - view product id \n 2 - To view product name \n 3 - To view manufacturer  name \n 4 - To view the product price \n 5 - To view the quantity \n 6 - To see no.of products you have & total stocks of all products \n 7 - To see all details"))
            if a==1: 
                print(" \n  Your product id is : ",self.products[pid])
            if a==2:
                print(" \n  Namae of your product :  ",self.products[pid][0])
            if a==3:
                print(" \n  Product Manufacturer Name is : ",self.products[pid][1])
            if a==4:
                print(" \n  Product price : ",self.products[pid][2])
            if a==5:
                 print(" \n  Current Stock : ",self.products[pid][3]) 
            if a==6:
                print(" \n  Total no.of products you have : ",len(list(self.products.keys())))
                m=0
                for i in self.products:
                    m+=i[3]
                print(" \n  Your total stock of all product : ",m)
            if a==7:
                print(" ")
                print(" \n  Your product id is : ",self.products[pid])
                print(" Namae of your product :  ",self.products[pid][0])
                print(" Product Manufacturer Name is : ",self.products[pid][1])
                print(" Product price : ",self.products[pid][2])
                print(" Current Stock : ",self.products[pid][3])
                                
                
        else:
            print(" \n  OOPS !! ...Your product id is not found ")
    
    def delet_product(self):             
        pid=input(" \n Enter your product id ")
        if pid in self.products:
            inp=input(" \n  Do you want to delet this product if Yes type  Y (else) type  N")
            if inp=="Y" or "y":
                      self.products.pop(pid)
                      print(" \n Your list was updated after removing that product ")
            if inp=="N" or "n":
                    pass
        else:
            
            print(" \n OOPS !!...Your product id was not found ")
                      
                      
    def menu(self): 
        
        while True:
                      
            x=int(input(" \n Enter \n 1 - To create product \n 2 - To View product details \n 3 - To update/change product details  \n 4 - To delet product  "))
            
            if x==1:
                self.create_product()
            elif x==2:
                self.view_product_details()
            elif x==3:
                self.update_product()
            elif x==4:
                self.delet_product()

            else:
                print("You had entered wrong input")
                      
          
                      
                      
class customer(amazon):
    
    def __init__(self):
        super().__init__()
        self.customers_details={}
        #self.customer_detail={}
        self.order_details={}
        self.sno=1
    def customer_register(self):
        
        
        self.cust_name=input("\n Enter your full name ")
        a=int(input("\n Enter your number , it must be 10 digits "))
        if len(str(a))==10:
            self.cust_contact_number=a
        else:
            print("\n Your mobail number does not contains 10 digits ")
        self.mail_id=input("\n Enter your mail-id ")
        self.address=input("\n Enter your address in a single line(ie without using enter key) ")
        self.password=input("Enter your password : ")
        s={}
        s["customer_name"]=self.cust_name
        s["customer_contact_number"]=self.cust_contact_number
        s["customer_mail_id"]=self.mail_id
        s["customer_address"]=self.address
        s["customer_password"]=self.password
        
        self.customers_details[self.cust_contact_number]=s
        
        print("\n Your registration process completed sucessfully ")
        
        print("\n customers_details \n\n ",self.customers_details)
        
    def customer_login(self):        
        num=int(input("\n Enter your contact number to loggin : "))
        if num in self.customers_details:
            pas=input("\n Enter your password")                         
            if self.customers_details[num]["customer_password"]==pas:
                print("\n Logged in sucessfully ")
                f=int(input("\n Enter 1 - New order \n 2 - Order history ")) # \n 3 - Cancel order
                if f==1:
                    k=1
                    for i in self.products:
                        print("\n The followings are the list that shows current availibility of the products & their details  ")
                        print("S.no-",k,"\n")                 
                        print("  Product ID         : ",i)
                        print("  Product name       : ",self.products[i][0])
                        print("  Manufacture name   : ",self.products[i][1])
                        print("  Price              : ",self.products[i][2])
                        print("  Available Quantity : ",self.products[i][3])
                        k+=1
                        
                    sel=input(" \n Enter the product ID of the product that you want to order ")
                    if sel in self.products:
                        
                        qt=int(input("\n Enter the no.of quantity do you want "))
                        if self.products[sel][3]>=qt:
                            print("\n The price for ",qt," quantity will be ",qt*self.products[sel][2]," if ok to continue order type 'y' ")
                            ops=input()
                            if ops=="y" or "Y":
                                di={}
                                d={}
                                self.products[sel][3]-=qt
                                d["number"]=num
                                d["product ID"]=sel
                                d["product name"]=self.products[sel][0]
                                d["quantity"]=qt
                                #di[self.sno]=d                  # id,name,qty
                                self.order_details[self.sno]=d   # numb: d(name,qty)
                                self.sno+=1
                                print("\n Your order has been created sucessfully ")
                        else:
                            print("\n Sorry there is only  ", self.products[sel][3]," quantity available in stock ")
                    else:
                        print("\n You had entered invalid product id ")
                            
       
                if f==2:
                    for i in self.order_details:
                        if num in self.order_details[i]["number"]:
                            print("\n History of product id - ",self.order_details[i]["product ID"],"  name - ",self.order_details[i]["product name"]," Quantity - ",self.order_details[i]["quantity"])
                    
                       
                        
                    print("-----------")
                
                        

                    
                
            else:
                print("\n You had entered wrong password")
        else:
            print("\n This number was not registered with us , please verify your number (or) please register first ")
            
            
    def menu(self):
        v=True
        
        while v:
            r=int(input("""Enter \n 1 - To create product \n 2 - To View product details \n 3 - To update/change product details  \n 4 - To delet product  \n 5 - For Customer register \n 6 - For Customer login \n 7 - To Exit"""))
            if r==1:
                self.create_product()
            elif r==2:
                self.view_product_details()
            elif r==3:
                self.update_product()
            elif r==4:
                self.delet_product()
            elif r==5:
                self.customer_register()
            elif r==6:
                self.customer_login()
            elif r==7:
                v=False
        

        else:
            print("You had entered wrong input")

            
            
                                               
c1=customer()                                                                                      
c1.menu()
                                    #
# Out:
# Enter
#  1 - To create product
#  2 - To View product details
#  3 - To update/change product details
#  4 - To delet product
#  5 - For Customer register
#  6 - For Customer login
#  7 - To Exit1
#
#   Create product ID  A1
#
#  Enter the product Name iphone
#
#  Enter the Manufacturer Name apple
#
#  Enter the price 10000
#
#  Enter the quantity of product 10
#
#   products in dict  {'A1': ['iphone', 'apple', 10000, 10]}
# Enter
#  1 - To create product
#  2 - To View product details
#  3 - To update/change product details
#  4 - To delet product
#  5 - For Customer register
#  6 - For Customer login
#  7 - To Exit4
#
#  Enter your product id A1
#
#   Do you want to delet this product if Yes type  Y (else) type  NY
#
#  Your list was updated after removing that product
# Enter
#  1 - To create product
#  2 - To View product details
#  3 - To update/change product details
#  4 - To delet product
#  5 - For Customer register
#  6 - For Customer login
#  7 - To Exit2
#
# ...

# %%
#### Log

Enter 
 1 - To create product 
 2 - To View product details 
 3 - To update/change product details  
 4 - To delet product  
 5 - For Customer register 
 6 - For Customer login 
 7 - To Exit1
 
  Create product ID  123
 
 Enter the product Name mobail
 
 Enter the Manufacturer Name mi
 
 Enter the price 15000
 
 Enter the quantity of product 5
 
  products in dict  {'123': ['mobail', 'mi', 15000, 5]}
Enter 
 1 - To create product 
 2 - To View product details 
 3 - To update/change product details  
 4 - To delet product  
 5 - For Customer register 
 6 - For Customer login 
 7 - To Exit1
 
  Create product ID  321
 
 Enter the product Name watch
 
 Enter the Manufacturer Name boat
 
 Enter the price 2000
 
 Enter the quantity of product 10
 
  products in dict  {'123': ['mobail', 'mi', 15000, 5], '321': ['watch', 'boat', 2000, 10]}
Enter 
 1 - To create product 
 2 - To View product details 
 3 - To update/change product details  
 4 - To delet product  
 5 - For Customer register 
 6 - For Customer login 
 7 - To Exit6

 Enter your contact number to loggin : 7402778577

 This number was not registered with us , please verify your number (or) please register first 
Enter 
 1 - To create product 
 2 - To View product details 
 3 - To update/change product details  
 4 - To delet product  
 5 - For Customer register 
 6 - For Customer login 
 7 - To Exit5

 Enter your full name Deepak

 Enter your number , it must be 10 digits 7402778577

 Enter your mail-id 123

 Enter your address in a single line(ie without using enter key) Erode,TN
Enter your password : 123

 Your registration process completed sucessfully 

 customers_details 

  {7402778577: {'customer_name': 'Deepak', 'customer_contact_number': 7402778577, 'customer_mail_id': '123', 'customer_address': 'Erode,TN', 'customer_password': '123'}}
Enter 
 1 - To create product 
 2 - To View product details 
 3 - To update/change product details  
 4 - To delet product  
 5 - For Customer register 
 6 - For Customer login 
 7 - To Exit6

 Enter your contact number to loggin : 7402778577

 Enter your password123

 Logged in sucessfully 

 Enter 1 - New order 
 2 - Order history 1

 The followings are the list that shows current availibility of the products & their details  
S.no- 1 

  Product ID         :  123
  Product name       :  mobail
  Manufacture name   :  mi
  Price              :  15000
  Available Quantity :  5

 The followings are the list that shows current availibility of the products & their details  
S.no- 2 

  Product ID         :  321
  Product name       :  watch
  Manufacture name   :  boat
  Price              :  2000
  Available Quantity :  10
 
 Enter the product ID of the product that you want to order 321

 Enter the no.of quantity do you want 2

 The price for  2  quantity will be  4000  if ok to continue order type 'y' 
y

 Your order has been created sucessfully 
Enter 
 1 - To create product 
 2 - To View product details 
 3 - To update/change product details  
 4 - To delet product  
 5 - For Customer register 
 6 - For Customer login 
 7 - To Exit7
You had entered wrong input

# %% [markdown]
# ## Tinder replica

# %%
class tinder:
    def __init__(self):
        self.user_details={}
        self.intrest=[]
        self.users_login={}
        self.dic1={}
        self.login=False
        self.all_users_details={}
        self.s=0
       # self.suggestion_profile={}
    
    
    def register(self):
        self.phone_number=int(input("Enter your phone number to register , it must be 10 digits : "))
        if len(str(self.phone_number))==10:
            if self.phone_number not in self.dic1:
                self.password=input("Create your password : ")
                a=self.phone_number
                self.dic1[self.phone_number]=self.password
                self.name=input("Enter your name ")
                self.dob=input("Enter your DOB ")
                self.email=input("Enter your mail-ID ")
                self.Gender=input("Enter your Gender (ie) M (or) F (or) B ")

                self.intrest=[]
                for i in range(2):
                    x=input("Enter your intrest ---each item after enter")
                    self.intrest.append(x.lower())
                print("Your intrest has been added sucessfully ")


                self.all_users_details[a]=[self.name,self.dob,self.email,self.Gender,self.intrest]
            else:
                print("Phone number alredy exist ... please use another number to register (or) Move to login ")
      
        else:
                print("You have entered wrong phone number ")
            
                
            
        
        
        
    def loggin(self):
        
        self.s=int(input("Please enter your number : "))
        if self.s in self.dic1:
            pas=input("Please enter your password  : ")
            if pas==self.dic1[self.s]:
                self.login=True
                print(" Loged in sucessfull ")
            else:
                print("You had entered wrong password !!! ")
                
    def show_profile(self):
        if self.login==True:
            print("Name    : ",self.all_users_details[self.s][0])
            print("DOB     : ",self.all_users_details[self.s][1])
            print("email   : ",self.all_users_details[self.s][2])
            print("Gender  : ",self.all_users_details[self.s][3])
            print("Intrest : ",self.all_users_details[self.s][4])
        else:
            print("please login and come to view your profile")
        
    def frds_suggestion(self):
        
        if self.login==True:
        
            
            match=[]
            print("\n"," The below shown suggetions are based on the similarity of intrest as same as you intrest ")
           
            for j in self.all_users_details :
                for i in self.all_users_details[self.s][4]:
                    if i in self.all_users_details[j][4]:
                        if self.s != j :
                            match.append(self.all_users_details[j][0])
            if match!=[]:
                for i in match:

                    print(" Yours friends suggestions are   :  ","\n","      ",i)
                  
            else:
                print(" No one is matching with your intrest ")
                
        else:
            print("please login and come to view suggestion ")
       
    
    def menu(self):
        
        ans=True
        
        while ans:
        
            i= int(input("Enter 1 for register , 2 for log in , 3 to see your friends suggestion"))
            if i==1:
                self.register()
            if i==2:
                self.loggin()
            if i==3:
                self.frds_suggestion()
                    
            
                
                
t1=tinder()


t1.menu()
# Out:
# Enter 1 for register , 2 for log in , 3 to see your friends suggestion2
# Please enter your number : 99887766
# Enter 1 for register , 2 for log in , 3 to see your friends suggestion2
# Please enter your number : 9988776655
# Enter 1 for register , 2 for log in , 3 to see your friends suggestion2
# Please enter your number : 9988776655
# Enter 1 for register , 2 for log in , 3 to see your friends suggestion2
# Please enter your number : 9988776655
# Enter 1 for register , 2 for log in , 3 to see your friends suggestion3
# please login and come to view suggestion
# Enter 1 for register , 2 for log in , 3 to see your friends suggestion2
# Please enter your number : 9988776655

# %%
A = {'name':'dave','interest':['art','books','swim','trek'],'gender':'F'}

B = {'name':'Ryan','interest':['art','reading','write','books'],'gender':'M'}

C

D

E

F


suggestion_pool=[]
    
for i in len(all_users_details):
    
    
    
    if len(set(A['interest']).intersection(i['interest']))>=2 and i['gender']==A['interested_in']:

        suggestion_pool.append(B)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <module>
#       1 A = {'name':'dave','interest':['art','books','swim','trek'],'gender':'F'}
#       3 B = {'name':'Ryan','interest':['art','reading','write','books'],'gender':'M'}
# ----> 5 C
#       8 suggestion_pool=[]
#      11 if len(set(A['interest']).intersection(B['interest']))>=2:
#
# NameError: name 'C' is not defined

# %%
suggestion_pool
# Out:
# [{'name': 'Ryan',
#   'interest': ['art', 'reading', 'write', 'books'],
#   'gender': 'M'}]
