# %%
data types:
    
Strings
Lists
Dictionaries
tuples
sets

# %%
L1 = ['apple','mango','banana','kiwi']

print(L1[0:len(L1):1])

print(L1[len(L1):-5:-1])

L1[::1]
L1[::-1]
# Out:
# ['apple', 'mango', 'banana', 'kiwi']
# ['kiwi', 'banana', 'mango', 'apple']

# %% [markdown]
# ### Strings

# %%
1. single quotes
2. double quotes
3. triple quotes # multiline strings

immutable
iterable
ordered

length of the string-- len()
membership operator works:
slicing works
indexing works

# %%
#membership operator works:
    
string = 'i will be attending a class this evening'

'class' not in string

# slicing

string[::-1]

# indexing (FW, BW)
# Out:
# 'gnineve siht ssalc a gnidnetta eb lliw i'

# %%
# to delete an object from memory

a = '3'
print(a)

del a

print(a)
# Out:
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-117e2e62601d> in <module>
#       4 del a
#       5
# ----> 6 print(a)
#
# NameError: name 'a' is not defined

# %%
del str

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
#capitalize ---make leading character in upper case and others lower case

string = "i will be attending a class this evening at 5"

string.capitalize()

string1 = "I Will Be attending a class this evening at 5"

string1.capitalize()

string2 = "@5 I Will Be attending a class this evening. All are invited."

string2.capitalize()

##title()--------makes first char of each word a upper case

string = "i will be attending a class this evening at 5"

string.title()
# Out:
# 'I Will Be Attending A Class This Evening At 5'

# %%
string = "i will be attending a class this evening at 5"

str1 = ''

for i in string:
    str1 = str1+i.capitalize()

    
print(str1)

str1 = ''

for i in string.split():
    str1 = str1+i.title()+' '

print(str1)
# Out:
# I WILL BE ATTENDING A CLASS THIS EVENING AT 5
# I Will Be Attending A Class This Evening At 5

# %%
### concatenation


string1 + ' .Other way of saying this is:---   '+ string2
# Out:
# 'I Will Be attending a class this evening at 5 .Other way of saying this is:---   @5 I Will Be attending a class this evening. All are invited.'

# %%
string5 = 'aa bb cc dd'
string5.title()

# to check ---istitle()
# Out:
# 'Aa Bb Cc Dd'

# %%
# lower()-----convert each letter of my string into lower case

string6 = 'I WILL be attending a class this evening at 5'
string6.lower()


# upper()


string7= 'I WILL be attending a class this evening at 5'
string7.upper()
# Out:
# 'I WILL BE ATTENDING A CLASS THIS EVENING AT 5'

# %%
string8= 'apple'

string8 == string8.upper().lower()
# Out:
# True

# %%
# alphanumeric

#combination of alphabets and numerics

#EDYODA12345--- Alpha numeric
#EDYODA---------Alpha
#12345----------numeric

# isalpha---- if all the characters in the string are alphabets?
# NOTE:       space is also not conidered as alpha----

string9 = 'Iboughttenapples'

string9.isalpha()

string10 = 'Ibought10apples'

not string10.isalnum()
# Out:
# False

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
### count ----- 3 argumnets taken where 2 are optional

### count('char',start,end)

string10 = 'I WILL be attending a class this evening at 5'

print(string10[10:14].count('e'))

string10.count(' ')
# Out:
# 1
# 9

# %%
string10[10:14]
# Out:
# 'atte'

# %%
string10.count('W',10,14)
# Out:
# 0

# %%
### join and split  "*".join(iterable)

string11 =  'I WILL be attending a class this evening at 5'

"**".join(string11)


# how you converted a tupe into a list----

B=('1','2','3','4')  ######### tuple
A = 'monkey'.join(B) ######### string
B=A.split('monkey')
B                    ######### list
# Out:
# ['1', '2', '3', '4']

# %%
L1 = [1,2,34,5] #### no integer elements

#"*".join()

#split()---- by default the argument is ---- space
#        ---- the output is a list
#split(sep=None, maxsplit=-1)

string12 = 'I WILL be attending a class this evening at 5'

string12.split()

string12.count(' ') == len(string12.split())-1
# Out:
# True

# %%
S ='Oh boy not again'

S.split(' ',2)


# count number of spaces:

len(S.split())-1
# Out:
# 3

# %%
S1 = 'Yogesh*12345*edyoda*2022'

# split this string as per the character == '_'

S1.split(' ',1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-231-1d816e4b1602> in <module>
#       3 # split this string as per the character == '_'
#       4
# ----> 5 S1.split('',1)
#
# ValueError: empty separator

# %%
S1 = 'Yogesh*12345*edyoda*2022'

# split this string as per the character == '_'

S1.split('5',1)
# Out:
# ['Yogesh*1234', '*edyoda*2022']

# %%
# replace() ----replace a substring in the string
#            ----three arguments (old,new,count)
#            -----count is optional

string12 = 'I WILL be attending a class this evening at 5'
string12.replace('5','5:30')

string12.replace('e','E',2)
# Out:
# 'I WILL bE attEnding a class this EvEning at 5'

# %%
#  use for loop and replace and turn 'e' into 'E'

s='I WILL be attending a class this evening at 5'

for i in s:
    string=s.replace("e","E")


print(string)


for i in s:
    if i =='e':
        string=s.replace("e","E")
        print(string)
        break
# Out:
# I WILL bE attEnding a class this EvEning at 5
# I WILL bE attEnding a class this EvEning at 5

# %%
#istitle()
#isupper()
#islower()


string13 = 'I AM Stuying At EDYODA'
string13.istitle()

string16 = 'I Am Stuying At Edyoda'
string16.istitle()
#istitle(string13)

string17 = 'I Am Stuying At Edyoda'
string17.isupper()
string17.islower()

string18= 'I AM STUDYING AT EDUYODA'
string18.isupper()


string18= 'I AM studying AT EDUYODA'

for i in string18.split():
    if not i.isupper():
        print(i,sep='')
    else:
        pass
# Out:
# studying

# %%
# input functions----takes only one optional argument that is prompt
# print()        ----object, sep='',end=''

#format()        ----- tomorrow

# Assignment:----
# How do you find how many nouns are there in a paragrpah?


Himalaya?
Virat kohli
Darjeeling tea
A, An, The

# %%
string = "i will be attending a class this evening at 5"
print(string.split())
B = string.split()



str1 = ''

for i in string.split():
    
    print(i.title())
    str1 = str1+i.title()+' '


    
    

print(str1)
# Out:
# ['i', 'will', 'be', 'attending', 'a', 'class', 'this', 'evening', 'at', '5']
# I
# Will
# Be
# Attending
# A
# Class
# This
# Evening
# At
# 5
# I Will Be Attending A Class This Evening At 5
